# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.rand(5)
# Out:
# array([0.78553011, 0.96944141, 0.37488288, 0.56798437, 0.71213249])

# %%
x= np.linspace(0,10,2)
y=mp.
plt.plot(x)
